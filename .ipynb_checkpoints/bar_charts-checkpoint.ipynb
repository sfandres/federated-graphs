# %% [markdown]
# **BAR CHARTS**

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %load_ext pycodestyle_magic

# %%
# %pycodestyle_on

# %%
# plt.rc('text', usetex=True)
# plt.rc('font', family='serif', size=15)

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# # Simple bar chart

# %% [markdown]
# ## Plot function

# %%
def simple_bar_plot(data_x, data_y,
                    x_axis_label=r'x axis label',
                    y_axis_label=r'y axis label',
                    plt_name='simple_bar_plot',
                    fig_size=(9, 5)):

    # Barplot.
    fig, ax = plt.subplots(figsize=fig_size)

    # Set bar width.
    barWidth = 0.4

    # Set y values.
    y = data_y

    # Set position of bar on X axis.
    x_pos = np.arange(len(y))

    # Make the plot.
    plt.bar(x_pos,
            y,
            width=barWidth,
            zorder=3,
            color='#005f8a',
            edgecolor='black',
            linewidth=.25,
            label=r'')

    plt.ylim(0, np.max(y) + np.max(y) * 0.1)

    # Add the numbers on top of each bar.
    for x in range(len(x_pos)):
        plt.text(x=x,
                 y=y[x],
                 s=r'{}'.format(y[x]),
                 ha='center',
                 va='bottom',
                 fontsize=13)

    # Add xticks on the middle of the group bars.
    plt.xticks([r for r in range(len(data_x))], data_x)

    # Set grid.
    # plt.grid(axis='y',
    #          color='gainsboro',
    #          linestyle='-',
    #          linewidth=0.2,
    #          zorder=0)

    # Remaining options.
    plt.xlabel(x_axis_label, labelpad=15, fontsize=17)
    plt.ylabel(y_axis_label, labelpad=15, fontsize=17)

    # Adjust margins.
    plt.gcf().subplots_adjust(bottom=0.15)
    plt.gcf().subplots_adjust(left=0.15)

    # Adjust X ticks.
    # fig.autofmt_xdate()

    # Plot.
    plt.show()

    # Save resulting figure in two formats.
    fig.savefig(f'output/{plt_name}.png',
                bbox_inches='tight')
    fig.savefig(f'output/{plt_name}.pdf',
                bbox_inches='tight')

# %% [markdown]
# ## Example

# %%
data_x = [2016 + x for x in range(0, 8)]
data_y = [x for x in range(10, 18)]
fig_size = (9, 5)

simple_bar_plot(
    data_x,
    data_y,
    'Year',
    'Number of articles published',
    '01-fl-articles',
    fig_size
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 5
#       2 data_y = [x for x in range(10, 18)]
#       3 fig_size = (9, 5)
# ----> 5 simple_bar_plot(
#       6     data_x,
#       7     data_y,
#       8     'Year',
#       9     'Number of articles published',
#      10     '01-fl-articles',
#      11     fig_size
#      12 )
#
# Cell In[6], line 65, in simple_bar_plot(data_x, data_y, x_axis_label, y_axis_label, plt_name, fig_size)
#      62 plt.show()
#      64 # Save resulting figure in two formats.
# ---> 65 fig.savefig(f'figures/{plt_name}.png',
#      66             bbox_inches='tight')
#      67 fig.savefig(f'figures/{plt_name}.pdf',
#      68             bbox_inches='tight')
#
# File ~/Documents/Git/graphs/graphs-conda/lib/python3.11/site-packages/matplotlib/figure.py:3328, in Figure.savefig(self, fname, transparent, **kwargs)
#    3324     for ax in self.axes:
#    3325         stack.enter_context(
#    3326             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3328 self.canvas.print_figure(fname, **kwargs)
#
# File ~/Documents/Git/graphs/graphs-conda/lib/python3.11/site-packages/matplotlib/backend_bases.py:2362, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2358 try:
#    2359     # _get_renderer may change the figure dpi (as vector formats
#    2360     # force the figure dpi to 72), so we need to set it again here.
#    2361     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2362         result = print_method(
#    2363             filename,
#    2364             facecolor=facecolor,
#    2365             edgecolor=edgecolor,
#    2366             orientation=orientation,
#    2367             bbox_inches_restore=_bbox_inches_restore,
#    2368             **kwargs)
#    2369 finally:
#    2370     if bbox_inches and restore_bbox:
#
# File ~/Documents/Git/graphs/graphs-conda/lib/python3.11/site-packages/matplotlib/backend_bases.py:2228, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2224     optional_kws = {  # Passed by print_figure for other renderers.
#    2225         "dpi", "facecolor", "edgecolor", "orientation",
#    2226         "bbox_inches_restore"}
#    2227     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2228     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2229         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2230 else:  # Let third-parties do as they see fit.
#    2231     print_method = meth
#
# File ~/Documents/Git/graphs/graphs-conda/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/Documents/Git/graphs/graphs-conda/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:458, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     453 """
#     454 Draw the canvas, then save it using `.image.imsave` (to which
#     455 *pil_kwargs* and *metadata* are forwarded).
#     456 """
#     457 FigureCanvasAgg.draw(self)
# --> 458 mpl.image.imsave(
#     459     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/Documents/Git/graphs/graphs-conda/lib/python3.11/site-packages/matplotlib/image.py:1687, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1685 pil_kwargs.setdefault("format", format)
#    1686 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1687 image.save(fname, **pil_kwargs)
#
# File ~/Documents/Git/graphs/graphs-conda/lib/python3.11/site-packages/PIL/Image.py:2428, in Image.save(self, fp, format, **params)
#    2426         fp = builtins.open(filename, "r+b")
#    2427     else:
# -> 2428         fp = builtins.open(filename, "w+b")
#    2430 try:
#    2431     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figures/01-fl-articles.png'

# %% [markdown]
# (intitle:"federated learning"), not including citations

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# # Bar chart with two columns with shared y axis

# %%
def double_bar_plot_shared_axis(data_x, data_y1, data_y2,
                                x_axis_label=r'x axis label',
                                y_axis_label=r'y1 axis label',
                                y1_label='y1 data label',
                                y2_label='y2 data label',
                                plt_name='double_bar_plot_shareed_axis',
                                fig_size=(12, 5)):

    # Figure.
    # fig = plt.figure(figsize=fig_size)  # Create matplotlib figure
    # ax = fig.add_subplot(111)  # Create matplotlib axes

    # Barplot.
    fig, ax = plt.subplots(figsize=fig_size)

    # Create another axes that shares the same x-axis as ax.
    # ax2 = ax.twinx()

    # Data.
    v1 = data_y1
    v2 = data_y2

    # Position of bar on X axis.
    barWidth = 0.42
    r1 = np.arange(len(v1))
    r2 = [x + barWidth for x in r1]

    # Bars.
    ax.bar(r1,
           v1,
           width=barWidth,
           color='#005f8a',
           edgecolor='black',
           linewidth=.1,
           label=r'{}'.format(y1_label),
           zorder=3)

    ax.set_ylabel(y_axis_label, labelpad=15, fontsize=13)  # 17
    max_y_value = np.maximum(v1, v2)
    ax.set_ylim(0, np.max(max_y_value) + np.max(max_y_value) * 0.1)

    ax.bar(r2,
           v2,
           width=barWidth,
           color='#ffa600',
           edgecolor='black',
           linewidth=.1,
           label=r'{}'.format(y2_label),
           zorder=3)

    # Annotations.
    for bar in ax.patches:

        # Using Matplotlib's annotate function and
        # passing the coordinates where the annotation shall be done
        # x-coordinate: bar.get_x() + bar.get_width() / 2
        # y-coordinate: bar.get_height()
        # free space to be left to make graph pleasing: (0, 8)
        # ha and va stand for the horizontal and vertical alignment
        ax.annotate(format(bar.get_height(), '.0f'),
                    (bar.get_x() + bar.get_width() / 2, bar.get_height()),
                    ha='center', va='center',
                    xytext=(0, 8),  # size=13,
                    textcoords='offset points')

    # Set X ticks and label.
    plt.xticks([r + barWidth - barWidth/2 for r in range(len(v1))],
               data_x)
    ax.set_xlabel(x_axis_label, labelpad=15, fontsize=13)  # 17

    # Legend.
    handles, labels = [], []
    for ax in fig.axes:
        for h, l in zip(*ax.get_legend_handles_labels()):
            handles.append(h)
            labels.append(l)

    plt.legend(handles, labels)

    # Set grid.
    # plt.grid(axis='y',
    #          color='gainsboro',
    #          linestyle='-',
    #          linewidth=0.2,
    #          zorder=0)

    # Margins.
    plt.gcf().subplots_adjust(bottom=0.15)
    plt.gcf().subplots_adjust(left=0.15)

    # Adjust X ticks.
    # fig.autofmt_xdate()

    # Plot.
    plt.show()

    # Save resulting figure in two formats.
    fig.savefig(f'output/{plt_name}.png',
                bbox_inches='tight')
    fig.savefig(f'output/{plt_name}.pdf',
                bbox_inches='tight')

# %%
data_x = [2016 + x for x in range(0, 7)]
data_scholar = [4, 7, 43, 231, 962, 2360, 4360]
data_scopus = [1, 7, 16, 156, 708, 1813, 2864]
fig_size = (9, 5)

double_bar_plot_shared_axis(
    data_x,
    data_scholar,
    data_scopus,
    x_axis_label='Year',
    y_axis_label='Number of articles',
    y1_label='Google Scholar',
    y2_label='Scopus',
    plt_name='02-fl-articles',
    fig_size=fig_size
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 6
#       3 data_scopus = [1, 7, 16, 156, 708, 1813, 2864]
#       4 fig_size = (9, 5)
# ----> 6 double_bar_plot_shared_axis(
#       7     data_x,
#       8     data_scholar,
#       9     data_scopus,
#      10     x_axis_label='Year',
#      11     y_axis_label='Number of articles',
#      12     y1_label='Google Scholar',
#      13     y2_label='Scopus',
#      14     plt_name='02-fl-articles',
#      15     fig_size=fig_size
#      16 )
#
# Cell In[8], line 98, in double_bar_plot_shared_axis(data_x, data_y1, data_y2, x_axis_label, y_axis_label, y1_label, y2_label, plt_name, fig_size)
#      95 plt.show()
#      97 # Save resulting figure in two formats.
# ---> 98 fig.savefig(f'figures/{plt_name}.png',
#      99             bbox_inches='tight')
#     100 fig.savefig(f'figures/{plt_name}.pdf',
#     101             bbox_inches='tight')
#
# File ~/Documents/Git/graphs/graphs-conda/lib/python3.11/site-packages/matplotlib/figure.py:3328, in Figure.savefig(self, fname, transparent, **kwargs)
#    3324     for ax in self.axes:
#    3325         stack.enter_context(
#    3326             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3328 self.canvas.print_figure(fname, **kwargs)
#
# File ~/Documents/Git/graphs/graphs-conda/lib/python3.11/site-packages/matplotlib/backend_bases.py:2362, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2358 try:
#    2359     # _get_renderer may change the figure dpi (as vector formats
#    2360     # force the figure dpi to 72), so we need to set it again here.
#    2361     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2362         result = print_method(
#    2363             filename,
#    2364             facecolor=facecolor,
#    2365             edgecolor=edgecolor,
#    2366             orientation=orientation,
#    2367             bbox_inches_restore=_bbox_inches_restore,
#    2368             **kwargs)
#    2369 finally:
#    2370     if bbox_inches and restore_bbox:
#
# File ~/Documents/Git/graphs/graphs-conda/lib/python3.11/site-packages/matplotlib/backend_bases.py:2228, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2224     optional_kws = {  # Passed by print_figure for other renderers.
#    2225         "dpi", "facecolor", "edgecolor", "orientation",
#    2226         "bbox_inches_restore"}
#    2227     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2228     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2229         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2230 else:  # Let third-parties do as they see fit.
#    2231     print_method = meth
#
# File ~/Documents/Git/graphs/graphs-conda/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/Documents/Git/graphs/graphs-conda/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:458, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     453 """
#     454 Draw the canvas, then save it using `.image.imsave` (to which
#     455 *pil_kwargs* and *metadata* are forwarded).
#     456 """
#     457 FigureCanvasAgg.draw(self)
# --> 458 mpl.image.imsave(
#     459     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/Documents/Git/graphs/graphs-conda/lib/python3.11/site-packages/matplotlib/image.py:1687, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1685 pil_kwargs.setdefault("format", format)
#    1686 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1687 image.save(fname, **pil_kwargs)
#
# File ~/Documents/Git/graphs/graphs-conda/lib/python3.11/site-packages/PIL/Image.py:2428, in Image.save(self, fp, format, **params)
#    2426         fp = builtins.open(filename, "r+b")
#    2427     else:
# -> 2428         fp = builtins.open(filename, "w+b")
#    2430 try:
#    2431     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figures/02-fl-articles.png'

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# # Bar chart with two columns without shared y axis

# %%
def double_bar_plot_no_shared_axis(data_x, data_y1, data_y2,
                                   x_axis_label=r'x axis label',
                                   y1_axis_label=r'y1 axis label',
                                   y2_axis_label=r'y2 axis label',
                                   y1_label='y1 data label',
                                   y2_label='y2 data label',
                                   plt_name='double_bar_plot_no_shared_axis',
                                   fig_size=(12, 5)):

    # Figure.
    # fig = plt.figure(figsize=fig_size)  # Create matplotlib figure
    # ax = fig.add_subplot(111)  # Create matplotlib axes

    # Barplot.
    fig, ax = plt.subplots(figsize=fig_size)

    # Create another axes that shares the same x-axis as ax.
    ax2 = ax.twinx()

    # Data.
    v1 = data_y1
    v2 = data_y2

    # Position of bar on X axis.
    barWidth = 0.4
    r1 = np.arange(len(v1))
    r2 = [x + barWidth for x in r1]

    # Bars.
    ax.bar(r1,
           v1,
           width=barWidth,
           color='#005f8a',
           edgecolor='black',
           linewidth=.25,
           label=r'{}'.format(y1_label),
           zorder=3)

    ax.set_ylabel(y1_axis_label, labelpad=15, fontsize=17)
    ax.set_ylim(0, np.max(v1) + np.max(v1) * 0.1)

    ax2.bar(r2,
            v2,
            width=barWidth,
            color='#ffa600',
            edgecolor='black',
            linewidth=.25,
            label=r'{}'.format(y2_label),
            zorder=3)

    ax2.set_ylabel(y2_axis_label, labelpad=15, fontsize=17)
    ax2.set_ylim(0, np.max(v2) + np.max(v2) * 0.1)

    # Annotations.
    for bar in ax.patches:

        # Using Matplotlib's annotate function and
        # passing the coordinates where the annotation shall be done
        # x-coordinate: bar.get_x() + bar.get_width() / 2
        # y-coordinate: bar.get_height()
        # free space to be left to make graph pleasing: (0, 8)
        # ha and va stand for the horizontal and vertical alignment
        ax.annotate(format(bar.get_height(), '.0f'),
                    (bar.get_x() + bar.get_width() / 2, bar.get_height()),
                    ha='center', va='center',
                    size=13, xytext=(0, 8),
                    textcoords='offset points')

    for bar in ax2.patches:

        # Using Matplotlib's annotate function and
        # passing the coordinates where the annotation shall be done
        # x-coordinate: bar.get_x() + bar.get_width() / 2
        # y-coordinate: bar.get_height()
        # free space to be left to make graph pleasing: (0, 8)
        # ha and va stand for the horizontal and vertical alignment
        ax2.annotate(format(bar.get_height(), '.0f'),
                     (bar.get_x() + bar.get_width() / 2, bar.get_height()),
                     ha='center', va='center',
                     size=13, xytext=(0, 8),
                     textcoords='offset points')

    # Set X ticks and label.
    plt.xticks([r + barWidth - barWidth/2 for r in range(len(v1))],
               data_x)
    ax.set_xlabel(x_axis_label, labelpad=15, fontsize=17)

    # Legend.
    handles, labels = [], []
    for ax in fig.axes:
        for h, l in zip(*ax.get_legend_handles_labels()):
            handles.append(h)
            labels.append(l)

    plt.legend(handles, labels)

    # Set grid.
    # plt.grid(axis='y',
    #          color='gainsboro',
    #          linestyle='-',
    #          linewidth=0.2,
    #          zorder=0)

    # Margins.
    plt.gcf().subplots_adjust(bottom=0.15)
    plt.gcf().subplots_adjust(left=0.15)

    # Adjust X ticks.
    # fig.autofmt_xdate()

    # Plot.
    plt.show()

    # Save resulting figure in two formats.
    fig.savefig(f'output/{plt_name}.png',
                bbox_inches='tight')
    fig.savefig(f'output/{plt_name}.pdf',
                bbox_inches='tight')

# %%
data_x = [2015 + x for x in range(0, 8)]
data_y1 = [x for x in range(10, 18)]
data_y2 = [0, 4, 7, 44, 231, 961, 2340, 3590]
fig_size = (12, 5)

double_bar_plot_no_shared_axis(
    data_x,
    data_y1,
    data_y2,
    x_axis_label='Year',
    y1_axis_label='Number of articles published 1',
    y2_axis_label='Number of articles published 2',
    y1_label='y1 data label',
    y2_label='y2 data label',
    plt_name='03-fl-articles',
    fig_size=fig_size
)

# %% [markdown]
# ***

# %% [markdown]
# ***
